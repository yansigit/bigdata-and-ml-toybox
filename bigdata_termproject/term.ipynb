# %%
import pandas as pd
from IPython.core.display import display

df = pd.read_csv("2019_관객수_및_매출액_월별.csv")

temp = ['년월']

i = 1
while i < df.iloc[4].size:
    temp.append(df.iloc[4][i])
    i+=1

df.columns = temp

display(df)
# Out:
#                                               년월  개봉편수   상영편수  \
# 0                              - 조회일: 2020-11-21   NaN    NaN
# 1   - 출처: 영화진흥위원회 통합전산망 (http://www.kobis.or.kr)   NaN    NaN
# 2                         ▶ 검색조건 [ 조회기간 : 2019 ]   NaN    NaN
# 3                                             년월    한국    NaN
# 4                                            NaN  개봉편수   상영편수
# 5                                        2019-01    46    130
# 6                                        2019-02    33    108
# 7                                        2019-03    46    134
# 8                                        2019-04    51    144
# 9                                        2019-05    59    164
# 10                                       2019-06    44    140
# 11                                       2019-07    54    139
# 12                                       2019-08    70    170
# 13                                       2019-09    61    179
# ...
